# %% [markdown]
# # 과제1 . 데이터 분석 정리

# %% [markdown]
# ##### [과제1]
# * 데이터를 불러오는 것 부터 데이터 탐색까지 파이썬으로 진행해야 하는 플로우 목차로 작성한다.
#     * 각 목차에 필요한 함수는?
#     * 각 목차에서 주의해야 할 점은 무었인가? (EX, EncodeDecodeError 등)
#     * 데이터 탐색 - 왜 해야 하는가?
#     * 데이터 탐색 시 필요한 함수는?

# %% [markdown]
# #### 1. 데이터 불러오기

# %%
import pandas as pd

# pd.read_csv() 함수로 데이터 불러오기

# %% [markdown]
# #### 2. 데이터 확인하기
# * .info()
# * .discribe()
# * .value_counts()

# %% [markdown]
# #### 3. 데이터 전처리 및 형변환 (결측치 제거)
# * .isnull()
# * .isnull().sum()
# * .fillna()

# %% [markdown]
# #### 4. 이상치 파악 처리 & 파생변수

# %% [markdown]
# #### 5. 데이터 탐색 (그룹별, 변수별)
# * 시각화 등으로 키워드 도출

# %%
from konlpy.tag import Okt
from kiwipiepy import Kiwi

#형태소 분석기를 선택하여 한줄 뽑아내기

# %%
import re
# re.sub("정규식","",문자열) 정규식으로 문자열 걸러내기

# %%
# 명사,동사 등 원하는 형태의 단어를 조건을 세워 뽑아내기
# 시각화 모듈에서 사용되는 형태로 단어 목록 추출 ([[],[],[]] 또는  [...])

# %%
# 수치화 라이브러리 이용하여 단어의 수치화 ( CountVectorizer)
# apriori , association_rules

# %%
# 데이터 시각화 (networkx,seaborn,matplotlib,LatentDirichletAllocation 등의 라이브러리 이용)

# %% [markdown]
# ##### [과제2]
# * 텍스트 데이터 분석 방법들과 그 과정을 문서로 작성한다.
#     * 1. 파일 불러오기
#     * 2. 형태소 분석기를 이용한 문자열 분리 ( 정규식 표현으로 필요없는 표현 제거)
#     * 3. 데이터를 선택한 시각화 라이브러리에서 요구하는 형태로 만든다
#     * 4. 시각화 하여 키워드 도출
#
#     #### 기타 질문
#
#     * 텍스트 데이터 분석이 힘든 이유? 같은 의미의 다양한 표현으로 해석에 오류가 있을 수 있음
#     * 텍스트 데이터 분석 방법 : 형태소 분석기를 이용한 문자열 분리
#     * 각각 방법마다 필요한 함수는?
#     * 시각화 해석은 어떻게 할까? AI와 충분히 논의 후 도출한다
