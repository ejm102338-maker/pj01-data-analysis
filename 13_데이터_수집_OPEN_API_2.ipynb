# %% [markdown]
# # 1. 데이터 수집 실습

# %%
# uv add requests python-dotenv
# python-dotenv : .env에 있는 정보 가져오는 도구
# requests : API 요청하는 도구

# %% [markdown]
# # API KEY 불러오기

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# API 확인
import os
print(os.getenv("SEOUL_PUBLIC_API_KEY"))

## !!!! API 유출 방지를 위해 출력이 확인되면 출력 내용을 지워야 함.
# Out:
# 656e646d43656a6d393774634c444e

# %%
# 데이터 사이트 : https://data.seoul.go.kr/dataList/OA-13252/F/1/datasetView.do
base_url = "http://openapi.seoul.go.kr:8088"
key = os.getenv("SEOUL_PUBLIC_API_KEY")
request_type = "json"
service = "tbCycleStationInfo"
start_index = 1
end_index = 5

url = f"{base_url}/{key}/{request_type}/{service}/{start_index}/{end_index}"
print(url)
# Out:
# http://openapi.seoul.go.kr:8088/656e646d43656a6d393774634c444e/json/tbCycleStationInfo/1/5

# %% [markdown]
# ## 2) 요청하기

# %%
import requests
response = requests.get(url)
print(response)
print(response.status_code)
#만약에 response.status가 200일 때만 다음을 진행하세요
# Out:
# <Response [200]>
# 200

# %% [markdown]
# ## 3) 데이터 확인하기

# %%
print(type(response.text))
print(response.text)
print(response.json())
# Out:
# <class 'str'>
# ...

# %%
data = response.json()
data
# Out:
# {'stationInfo': {'list_total_count': '3210',
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'STA_LOC': '마포구',
#     'RENT_ID': 'ST-10',
#     'RENT_NO': '00108',
#     'RENT_NM': '서교동 사거리',
#     'RENT_ID_NM': '108. 서교동 사거리',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 마포구 양화로 93',
#     'STA_ADD2': '427',
#     'STA_LAT': '37.55274582',
#     'STA_LONG': '126.91861725',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '1'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-100',
#     'RENT_NO': '00503',
#     'RENT_NM': '더샵스타시티 C동 앞',
#     'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 광진구 아차산로 262',
#     'STA_ADD2': '더샵스타시티 C동 앞',
#     'STA_LAT': '37.53666687',
#     'STA_LONG': '127.07359314',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '2'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1000',
#     'RENT_NO': '00729',
#     'RENT_NM': '서부식자재마트 건너편',
# ...

# %%
data.keys()
# Out:
# dict_keys(['stationInfo'])

# %%
data["stationInfo"]
# Out:
# {'list_total_count': '3210',
#  'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#  'row': [{'STA_LOC': '마포구',
#    'RENT_ID': 'ST-10',
#    'RENT_NO': '00108',
#    'RENT_NM': '서교동 사거리',
#    'RENT_ID_NM': '108. 서교동 사거리',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 마포구 양화로 93',
#    'STA_ADD2': '427',
#    'STA_LAT': '37.55274582',
#    'STA_LONG': '126.91861725',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '1'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-100',
#    'RENT_NO': '00503',
#    'RENT_NM': '더샵스타시티 C동 앞',
#    'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 광진구 아차산로 262',
#    'STA_ADD2': '더샵스타시티 C동 앞',
#    'STA_LAT': '37.53666687',
#    'STA_LONG': '127.07359314',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '2'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1000',
#    'RENT_NO': '00729',
#    'RENT_NM': '서부식자재마트 건너편',
#    'RENT_ID_NM': '729. 서부식자재마트 건너편',
#    'HOLD_NUM': '10',
# ...

# %%
items = data["stationInfo"]["row"]
print(len(items))
print(items)
# Out:
# 5
# ...

# %% [markdown]
# ## 4) 데이터 요청 제한 확인하기

# %%
# 데이터 사이트 : https://data.seoul.go.kr/dataList/OA-13252/F/1/datasetView.do
base_url = "http://openapi.seoul.go.kr:8088"
key = os.getenv("SEOUL_PUBLIC_API_KEY")
request_type = "json"
service = "tbCycleStationInfo"
start_index = 1
end_index = 1000

# url = f"{base_url}/{key}/{request_type}/{service}/{start_index}/{end_index}"
# print(url)
# Out:
# http://openapi.seoul.go.kr:8088/656e646d43656a6d393774634c444e/json/tbCycleStationInfo/1/1000

# %%
response = requests.get(url)
print(response)
print(type(response.text))
print(response.text)
print(response.json())
data = response.json()
items = data["stationInfo"]["row"]
# Out:
# <Response [200]>
# <class 'str'>
# ...

# %%
total_cnt = data["stationInfo"]["list_total_count"]
print(type(total_cnt))
# Out:
# <class 'str'>

# %%
# 한번요청할때 1,000 행만 가능하다.
## 전체가 3,210... 4번요청
## startl - end
## 1 - 1000
## 1001 - 2000
## 2001 - 3000
## 3001 - 3210

# %%
# start = 1 변수를 만든다
# 4번 반복하는 반복문을 반든다
# 반복할때 마다 end를 생성하고, start,end를출력한다 
# start, end가 반영된 url을 만든다
# url을 요청한다
# 요청ㅇ받은 데이터에서 item을 추출한다
# start를 업데이트 한다
# 반복문이 끝난 후 item_list의 갯수를 출력한다. - 3210개가 맞는지 ㅣ확ㄷ인
# 데이터프레임으로 바꾼다
# 데이터를 저장한다.

total_cnt = int(data["stationInfo"]["list_total_count"])
total_page = int(total_cnt / 1000)

if total_cnt % 1000 > 0: total_page += 1

item_list = []

#for i in range(total_page) :
for i in range(1,4000,1000) :
    if i < total_cnt :  
        #start = (i*1000) +1
        start = i-1
        end = start + 999
        #if end > total_cnt : end = total_cnt
        
        url = f"{base_url}/{key}/{request_type}/{service}/{start}/{end}"
        response = requests.get(url)
        data = response.json()
        print("받은 데이터 : ",len(data["stationInfo"]["row"]))
        end_i = 1
        for x in data["stationInfo"]["row"] : 
            item_list.append(x) 
    else : 
        break
    
    print(start,end)

    i += 1 

print(len(item_list))
# Out:
# 받은 데이터 :  999
# 0 999
# 받은 데이터 :  1000
# 1000 1999
# 받은 데이터 :  1000
# 2000 2999
# 받은 데이터 :  211
# 3000 3999
# 3210

# %%
import pandas as pd

item_list_df = pd.DataFrame(item_list)

# %%
item_list_df.head(20)
# Out:
#    STA_LOC  RENT_ID RENT_NO         RENT_NM           RENT_ID_NM HOLD_NUM  \
# 0      마포구    ST-10   00108         서교동 사거리         108. 서교동 사거리       12
# 1      광진구   ST-100   00503     더샵스타시티 C동 앞     503. 더샵스타시티 C동 앞       15
# 2      양천구  ST-1000   00729     서부식자재마트 건너편     729. 서부식자재마트 건너편       10
# 3      양천구  ST-1002   00731    서울시 도로환경관리센터    731. 서울시 도로환경관리센터       10
# 4      양천구  ST-1003   00732           신월중학교           732. 신월중학교       10
# 5      양천구  ST-1004   00733     신정이펜하우스314동     733. 신정이펜하우스314동       10
# 6      양천구  ST-1005   00734        신트리공원 입구        734. 신트리공원 입구       10
# 7      양천구  ST-1006   00735          영도초등학교          735. 영도초등학교       10
# 8      양천구  ST-1007   00736           오솔길공원           736. 오솔길공원       10
# 9      양천구  ST-1008   00737            장수공원            737. 장수공원       20
# 10     광진구   ST-101   00504       신자초교입구교차로       504. 신자초교입구교차로        9
# 11     양천구  ST-1010   00739           신월사거리           739. 신월사거리       13
# ...

# %%
item_list_df.to_csv("./data/서울시자전거대여소점포(20260127).csv")

# %% [markdown]
# # 2. 공공데이터 포털

# %%
from dotenv import load_dotenv
import os
load_dotenv()

base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"
key = os.getenv("PUBLIC_DATDA_API_KEY")

searchYearCd = 2017
siDo = 11
guGun = 680
request_type = "json"
numOfRows = 12
pageNo = 1

# %%
# 2. 공공데이터포털 ( 법규위반별 교통사고 다발지역 )

# %% [markdown]
# ### 1) URL 만들기

# %%
# https://www.code.go.kr/stdcode/regCodeL.do 법정동 코드찾기
# base_url?요청파라미터=값
url = f"{base_url}?ServiceKey={key}&searchYearCd={searchYearCd}&siDo={siDo}&guGun={guGun}&type={request_type}&numOfRows={numOfRows}&pageNo={pageNo}"

# %% [markdown]
# ### 2) 요청하기

# %%
import requests
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ### 3) 데이터 확인하기

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['resultCode', 'resultMsg', 'items', 'totalCount', 'numOfRows', 'pageNo'])

# %%
data["items"]
# Out:
# {'item': [{'afos_fid': 6423519,
#    'afos_id': '01',
#    'bjd_cd': '1168010100',
#    'spot_cd': '11680001',
#    'sido_sgg_nm': '서울특별시 강남구1',
#    'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)',
#    'occrrnc_cnt': 9,
#    'caslt_cnt': 13,
#    'dth_dnv_cnt': 0,
#    'se_dnv_cnt': 4,
#    'sl_dnv_cnt': 7,
#    'wnd_dnv_cnt': 2,
# ...

# %% [markdown]
# ### 4) 데이터 수집하기

# %%
print(len(data["items"]["item"]))
item_list = data["items"]["item"]
# Out:
# 12

# %%
import pandas as pd
df = pd.DataFrame(item_list)

# %%
df
# Out:
#     afos_fid afos_id      bjd_cd   spot_cd sido_sgg_nm  \
# 0    6423519      01  1168010100  11680001  서울특별시 강남구1
# 1    6423685      01  1168010600  11680002  서울특별시 강남구2
# 2    6423402      01  1168010100  11680003  서울특별시 강남구3
# 3    6423999      01  1168010100  11680004  서울특별시 강남구4
# 4    6423498      01  1168010500  11680005  서울특별시 강남구5
# 5    6423385      01  1168010500  11680006  서울특별시 강남구6
# 6    6423441      01  1168010100  11680007  서울특별시 강남구7
# 7    6424000      01  1168011500  11680008  서울특별시 강남구8
# 8    6424126      01  1168010100  11680009  서울특별시 강남구9
# 9    6424335      02  1168011800  11680001  서울특별시 강남구1
# 10   6424337      02  1168010800  11680002  서울특별시 강남구2
# 11   6424336      02  1168010100  11680003  서울특별시 강남구3
#
#                       spot_nm  occrrnc_cnt  caslt_cnt  dth_dnv_cnt  \
# 0       서울특별시 강남구 역삼동(역삼역 부근)            9         13            0
# 1      서울특별시 강남구 대치동(학여울역 부근)            8         12            0
# ...

# %% [markdown]
# ### 5) 데이터프레임 만들기 &저장하기

# %%
df.to_csv("./data/기술문서_한국도로교통공단_법규위반별 사고다발지역 정보_11680.hwp")

# %% [markdown]
# ### (과제1) 연도 기간을 설정해서 반복하려면 어떻게 해아하나?

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"
key = os.getenv("PUBLIC_DATDA_API_KEY")

# searchYearCd = 2017 반복문
siDo = 11
guGun = 680
request_type = "json"
numOfRows = 12
pageNo = 1

# %%
# 뭘 반복할 것인가 2015~ 2019까지
import requests
import pandas as pd

data_list = []
for searchYearCd in range(2020,2024):
    url = f"{base_url}?ServiceKey={key}&searchYearCd={searchYearCd}&siDo={siDo}&guGun={guGun}&type={request_type}&numOfRows={numOfRows}&pageNo={pageNo}"
    response = requests.get(url)

    if response.status_code != "200" : break

    data = response.json()
    item_list = data["items"]["item"]
    data_list.extend(item_list)

df = pd.DataFrame(data_list)

#df.to_csv("./data/기술문서_한국도로교통공단_법규위반별 사고다발지역 정보_년도별.hwp")

# %%
# 연도 기간을 설정해서 반복문으로 데이터를 수집할 수있나요?
df.head()

# %% [markdown]
# ### (과제 2) 여러시도 데이터를 반복문으로 가져올 수 있나요?

# %%
import requests
import pandas as pd
base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"
key = os.getenv("PUBLIC_DATDA_API_KEY")

searchYearCd = 2017
siDo = 11             # 반복문마다 변함
guGun = 680           # 반복문마다 변함
request_type = "json"
numOfRows = 12
pageNo = 1

# %%
# 뭘 반복 할 것인가?
# 변수 리스트로 정의해보자
target = [(11,680),(41,135)]
target = [{"siDo":11,"guGun":680},{"siDo":41,"guGUn":135}]

data_list = []
for x in target:
    siDo = x["siDo"]
    guGun = x["guGun"]
    url = f"{base_url}?ServiceKey={key}&searchYearCd={searchYearCd}&siDo={siDo}&guGun={guGun}&type={request_type}&numOfRows={numOfRows}&pageNo={pageNo}"
    response = requests.get(url)

    if response.status_code != "200" : break

    data = response.json()
    item_list = data["items"]["item"]
    data_list.extend(item_list)

# %%
df = pd.DataFrame(data_list)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### (과제3) 법정동코드 API로 불러와서 데이터로 저장하기

# %%
from dotenv import load_dotenv
from urllib.parse import unquote
import os
import requests
import pandas as pd
load_dotenv()

base_url = "http://apis.data.go.kr/1741000/StanReginCd/getStanReginCdList"
ServiceKey = unquote(os.getenv("PUBLIC_DONG_API_KEY")) #인코딩 되기 전
pageNo = 1
numOfRows = 3
data_type="json"
localadd_nm = "서울특별시"

params = {
    "ServiceKey" : ServiceKey,
    "pageNo" : pageNo,
    "numOfRows" : numOfRows,
    "type" : data_type,
    "localadd_nm" : localadd_nm
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 from urllib.parse import unquote
# ----> 3 dong_key = unquote(os.getenv("PUBLIC_DONG_API_KEY"))
#       5 base_url = "http://apis.data.go.kr/1741000/StanReginCd/getStanReginCdList"
#       6 ServiceKey = dong_key #인코딩 되기 전
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\urllib\parse.py:687, in unquote(string, encoding, errors)
#     685 if isinstance(string, bytes):
#     686     return unquote_to_bytes(string).decode(encoding, errors)
# --> 687 if '%' not in string:
#     688     string.split
#     689     return string
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
response = requests.get(base_url,params=params)

# %%
item_list = data["StanReginCd"][1]["row"]

if response.status_code != "200":
    print("문제가 생겼어요")

response.text

# %% [markdown]
# # 3. 네이버 API

# %% [markdown]
# ### 방법 1

# %%
from dotenv import load_dotenv
import os
load_dotenv()

base_url = "https://openapi.naver.com/v1/search/news.json"

X_Naver_Client_Id = os.getenv("X-Naver-Client-Id")
X_Naver_Client_Secret = os.getenv("X-Naver-Client-Secret")

# %%
import urllib
query = urllib.parse.quote("인공지능") # 인코딩 필요
display = 100
start = 1
sort = ""

# %% [markdown]
# ### 방법 2

# %%
base_url = "https://openapi.naver.com/v1/search/news.json"
params = {
    "query" : "AI", # 인코딩 안해도 됨
    "display" : 100,
    "start" : 1,
    "sort" : "sim"
}

# %% [markdown]
# ### 2) 요청하기

# %%
import requests
# 헤더
headers = {
    "X-Naver-Client-Id" : X_Naver_Client_Id,
    "X-Naver-Client-Secret" : X_Naver_Client_Secret
}

# %% [markdown]
# ### 방법 1

# %%
response = requests.get(url,headers=headers)

# %% [markdown]
# ### 방법 2

# %%
response = requests.get(url,params=params,headers=headers)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ### 3) 데이터 확인하기

# %%
print(response.text)
data = response.json()
# Out:
# {
# 	"lastBuildDate":"Tue, 27 Jan 2026 11:20:13 +0900",
# 	"total":48,
# 	"start":1,
# 	"display":48,
# 	"items":[
# 		{
# 			"title":"Open Letters: Our Opinion-Writing Contest",
# 			"originallink":"https:\/\/www.nytimes.com\/2026\/01\/22\/learning\/open-letters-our-opinion-writing-contest.html?partner=naver",
# 			"link":"https:\/\/www.nytimes.com\/2026\/01\/22\/learning\/open-letters-our-opinion-writing-contest.html?partner=naver",
# 			"description":"your <b>query<\/b> in the comments or write to us at LNFeedback@nytimes.com. How is this contest... Students can <b>search<\/b> for articles using the <b>search<\/b> tool on our home page. How do my students prove to me... ",
# 			"pubDate":"Fri, 23 Jan 2026 03:24:00 +0900"
# 		},
# 		{
# 			"title":"넥스트아이티에스, 텍스트 너머 모든 데이터를 이해하는 <b>AI<\/b> 솔루션으로...",
# 			"originallink":"https:\/\/www.venturesquare.net\/1019745",
# 			"link":"https:\/\/www.venturesquare.net\/1019745",
# ...

# %% [markdown]
# ### 4) 데이터 수집하기

# %%
print(data.keys())
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
item_list = data["items"]

# %% [markdown]
# ### 5) 데이터 프레임 만들기 & 저장하기

# %%
import pandas as pd

df = pd.DataFrame(item_list)

# %%
df.to_csv("./data/네이버검색_인공지능_csv")

# %%
df.head()
# Out:
#                                                title  \
# 0          Open Letters: Our Opinion-Writing Contest
# 1   넥스트아이티에스, 텍스트 너머 모든 데이터를 이해하는 <b>AI</b> 솔루션으로...
# 2  <b>AI</b>가 매체 방문자를 집어삼키고 있는데...“급격한 트래픽 감소의 대안...
# 3  Interview: “Our finance-specific <b>AI</b> age...
# 4                       Who Pays When A.I. Is Wrong?
#
#                                         originallink  \
# 0  https://www.nytimes.com/2026/01/22/learning/op...
# 1              https://www.venturesquare.net/1019745
# 2                   http://www.breaknews.com/1159466
# 3  https://www.chosun.com/english/people-en/2025/...
# 4  https://www.nytimes.com/2025/11/12/business/me...
#
#                                                 link  \
# 0  https://www.nytimes.com/2026/01/22/learning/op...
# 1              https://www.venturesquare.net/1019745
# 2                   http://www.breaknews.com/1159466
# 3  https://n.news.naver.com/mnews/article/023/000...
# ...

# %%
params = {
    "query" : "정부", # 인코딩 안해도 됨
    "display" : 100,
    "start" : 1,
    "sort" : "sim"
}
response = requests.get(base_url,params=params,headers=headers)
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# {
# 	"lastBuildDate":"Tue, 27 Jan 2026 11:23:29 +0900",
# 	"total":27743203,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"김동관, 캐나다 잠수함 세일즈 선봉 선다…&quot;<b>정부<\/b>와 원팀&quot;",
# 			"originallink":"https:\/\/www.newsis.com\/view\/NISX20260126_0003490676",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/003\/0013731664?sid=101",
# 			"description":"김 부회장은 <b>정부<\/b> 특사단과 보폭을 맞춰 한화오션을 중심으로 한 에너지·조선 연계 협력과 현지 산업... 27일 재계에 따르면 김동관 부회장은 캐나다 현지에서 강훈식 대통령비서실장을 비롯한 <b>정부<\/b> 특사단에 합류한다.... ",
# 			"pubDate":"Tue, 27 Jan 2026 08:00:00 +0900"
# 		},
# 		{
# 			"title":"“BTS 공연 더 해달라”…멕시코 대통령, 韓 <b>정부<\/b>에 공식 요청",
# 			"originallink":"https:\/\/biz.chosun.com\/topics\/topics_social\/2026\/01\/27\/O5QZM6IGBND3XNY7INXFAYZ5KY\/?utm_source=naver&utm_medium=original&utm_campaign=biz",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/366\/0001138623?sid=102",
# ...

# %% [markdown]
# # 4. Youtue API 사용하기

# %%
import os
key = os.getenv("YOUTUBE_API_KEY")

# %%
base_url = "https://www.googleapis.com/youtube/v3/commentThreads"

part = "snippet"
videoId = "_xOnGP_Js1A"                # 댓글 수집할 영상
key = os.getenv("YOUTUBE_API_KEY")
maxResults = 100                       # 최대 100개
textFormat = "plainText"

url = f"{base_url}?part={part}&videoId={videoId}&key={key}&maxResults={maxResults}&textFormat={textFormat}"
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_xOnGP_Js1A&key=AIzaSyChFU_-8kBZuR9tF0qp5Jzi9IWnlHLXjqs&maxResults=100&textFormat=plainText

# %%
import requests

response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# {
#   "kind": "youtube#commentThreadListResponse",
#   "etag": "0H_omccYCOdY4ipo27wSrvcfSGI",
#   "nextPageToken": "Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSUlCZ0FFZ1VJblNBWUFSSUZDS2dnR0FBU0JRaUhJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==",
#   "pageInfo": {
#     "totalResults": 100,
#     "resultsPerPage": 100
#   },
#   "items": [
#     {
#       "kind": "youtube#commentThread",
#       "etag": "Bsm7NeEj6SF-g-0lzkzDNNfoxCk",
#       "id": "Ugz5HudBVpzywkfF0mN4AaABAg",
#       "snippet": {
#         "channelId": "UCsjD7wxKCD8C62_idZQdGJg",
#         "videoId": "_xOnGP_Js1A",
#         "topLevelComment": {
#           "kind": "youtube#comment",
#           "etag": "4rn9srjNeDUGEOIl1nD6_R3kzfI",
#           "id": "Ugz5HudBVpzywkfF0mN4AaABAg",
#           "snippet": {
#             "channelId": "UCsjD7wxKCD8C62_idZQdGJg",
#             "videoId": "_xOnGP_Js1A",
#             "textDisplay": "아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.",
# ...

# %%
# Youtube API 댓글 수집은 한번 요청할때 maxREsults 100까지만 쓸 수 있다.
# 1번 요청하고,그 다음 요청 할 때 nextPageToken 파라미터도 함께 넣어줘야한다.

# %%
# 1. 변수 설정 : count(진행상황을 보기 위함),nextPageToken=None,item_list(데이터 수집 바구니),max_rep(최대반복수)
# 2. max_rep 만큼 반복문
# 3. API 요청
# 4. 응답 받아온다
# 5. nextPageToken 추출해서 변수 값을 업데이트 한다. nextPageToken =data.get("nextPageKoken")
#    조건 : 만약에 data["nextPageToken"] 이 없다면 반복문 중지
# 6. 데이터를 수집한다.
# 7. data_list에 담는다.
# 8. count를 업데이트 한다.

# %%
data = response.json()
data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '0H_omccYCOdY4ipo27wSrvcfSGI',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSUlCZ0FFZ1VJblNBWUFSSUZDS2dnR0FBU0JRaUhJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Bsm7NeEj6SF-g-0lzkzDNNfoxCk',
#    'id': 'Ugz5HudBVpzywkfF0mN4AaABAg',
#    'snippet': {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#     'videoId': '_xOnGP_Js1A',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4rn9srjNeDUGEOIl1nD6_R3kzfI',
#      'id': 'Ugz5HudBVpzywkfF0mN4AaABAg',
#      'snippet': {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#       'videoId': '_xOnGP_Js1A',
#       'textDisplay': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#       'textOriginal': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#       'authorDisplayName': '@새벽초승달-b5l',
# ...

# %%
data["pageInfo"]["totalResults"]
# Out:
# 100

# %%
items = data["items"]
items
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'Bsm7NeEj6SF-g-0lzkzDNNfoxCk',
#   'id': 'Ugz5HudBVpzywkfF0mN4AaABAg',
#   'snippet': {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#    'videoId': '_xOnGP_Js1A',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '4rn9srjNeDUGEOIl1nD6_R3kzfI',
#     'id': 'Ugz5HudBVpzywkfF0mN4AaABAg',
#     'snippet': {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#      'videoId': '_xOnGP_Js1A',
#      'textDisplay': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#      'textOriginal': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#      'authorDisplayName': '@새벽초승달-b5l',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lFFW-nj60JfhTG590s75U0dWxzJiGsU07Mq2tqA7-t2yj2XpI=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@%EC%83%88%EB%B2%BD%EC%B4%88%EC%8A%B9%EB%8B%AC-b5l',
#      'authorChannelId': {'value': 'UCIMy1QmzWBCYeCpACt_H3jg'},
#      'canRate': True,
#      'viewerRating': 'none',
# ...

# %%
count = 0
nextPageToken = None
item_list = []

max_rep = data["pageInfo"]["totalResults"]
nextPageToken = data["nextPageToken"]

# %%
print(type(max_rep))
# Out:
# <class 'int'>

# %%
print(len(items))
# Out:
# 100

# %%
params = {
    "part" : part, # 인코딩 안해도 됨
    "videoId" : videoId,
    "key" : os.getenv("YOUTUBE_API_KEY"),
    "maxResults" : maxResults,
    "textFormat" : textFormat,
    "nextPageToken" : nextPageToken
}

print(params["nextPageToken"])
# Out:
# Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWtnR0FBU0JRaWRJQmdCSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==

# %%
    #url = f"{base_url}?part={part}&videoId={videoId}&key={key}&maxResults={maxResults}&textFormat={textFormat}&nextPageToken={nextPageToken}"
item_list = []
# for i in range(0,max_rep-1):
#     item_list.append(items[i]["snippet"]["topLevelComment"]["snippet"] 
                     
# response = requests.get(base_url,params=params)
# data = response.json()
# items = data["items"]
# params["nextPageToken"] = data["nextPageToken"]
# max_rep = data["pageInfo"]["totalResults"]
#

for i in range(0,len(items)-1):
    item_list.append(items[i]["snippet"]["topLevelComment"]["snippet"])

page = 1
while nextPageToken : 
    for i in range(0,range(0,len(items)-1)):
        item_list.append(items[i]["snippet"]["topLevelComment"]["snippet"])

    if nextPageToken :  
        page += 1        
        params["nextPageToken"] = nextPageToken
        print(page,nextPageToken)
        response = requests.get(base_url,params=params)
        data = response.json()
        items = data["items"]
        nextPageToken = data["nextPageToken"]
        max_rep = data["pageInfo"]["totalResults"]
    else : break
# Out:
# 2 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpSklCZ0FFZ1VJblNBWUFSSUZDS2dnR0FBU0JRaUlJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# 3 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpb0lCZ0FFZ1VJaHlBWUFCSUZDSWdnR0FBU0JRaUpJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# 4 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpZElCZ0JFZ1VJaVNBWUFCSUZDSWdnR0FBU0JRaW9JQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# 5 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpb0lCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBU0JRaUpJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# 6 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNLZ2dHQUFTQlFpSklCZ0FFZ1VJblNBWUFSSUZDSWNnR0FBU0JRaUlJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# 7 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSElCZ0FFZ1VJblNBWUFSSUZDS2dnR0FBU0JRaUlJQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# 8 Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpZElCZ0JFZ1VJaUNBWUFCSUZDSWtnR0FBU0JRaW9JQmdBSWc0S0RBamcyTXZIQmhDbzZyV1JBUQ==
# ...

# %%
dic_list = pd.DataFrame(item_list)

# %%
dic_list.head()
print(len(dic_list))
# Out:
# 17919

# %% [markdown]
# # 4. 데이터 수집하기

# %%
# 똑같은 키를 딕셔너리가 여러개 보여있는 리스트르 찾아야 한다.
items = data["items"]
items
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'Bsm7NeEj6SF-g-0lzkzDNNfoxCk',
#   'id': 'Ugz5HudBVpzywkfF0mN4AaABAg',
#   'snippet': {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#    'videoId': '_xOnGP_Js1A',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '4rn9srjNeDUGEOIl1nD6_R3kzfI',
#     'id': 'Ugz5HudBVpzywkfF0mN4AaABAg',
#     'snippet': {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#      'videoId': '_xOnGP_Js1A',
#      'textDisplay': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#      'textOriginal': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#      'authorDisplayName': '@새벽초승달-b5l',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lFFW-nj60JfhTG590s75U0dWxzJiGsU07Mq2tqA7-t2yj2XpI=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@%EC%83%88%EB%B2%BD%EC%B4%88%EC%8A%B9%EB%8B%AC-b5l',
#      'authorChannelId': {'value': 'UCIMy1QmzWBCYeCpACt_H3jg'},
#      'canRate': True,
#      'viewerRating': 'none',
# ...

# %%
items[0]["snippet"]["topLevelComment"]["snippet"]
# Out:
# {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#  'videoId': '_xOnGP_Js1A',
#  'textDisplay': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#  'textOriginal': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#  'authorDisplayName': '@새벽초승달-b5l',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lFFW-nj60JfhTG590s75U0dWxzJiGsU07Mq2tqA7-t2yj2XpI=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/@%EC%83%88%EB%B2%BD%EC%B4%88%EC%8A%B9%EB%8B%AC-b5l',
#  'authorChannelId': {'value': 'UCIMy1QmzWBCYeCpACt_H3jg'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 0,
#  'publishedAt': '2026-01-26T23:37:51Z',
#  'updatedAt': '2026-01-26T23:37:51Z'}

# %%
params = {
    "query" : "정부", # 인코딩 안해도 됨
    "display" : 100,
    "start" : 1,
    "sort" : "sim"
}

item_list = []

for item in items :
    item_list.append(items[0]["snippet"]["topLevelComment"]["snippet"])

item_list
# Out:
# [{'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#   'videoId': '_xOnGP_Js1A',
#   'textDisplay': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#   'textOriginal': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#   'authorDisplayName': '@새벽초승달-b5l',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lFFW-nj60JfhTG590s75U0dWxzJiGsU07Mq2tqA7-t2yj2XpI=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelUrl': 'http://www.youtube.com/@%EC%83%88%EB%B2%BD%EC%B4%88%EC%8A%B9%EB%8B%AC-b5l',
#   'authorChannelId': {'value': 'UCIMy1QmzWBCYeCpACt_H3jg'},
#   'canRate': True,
#   'viewerRating': 'none',
#   'likeCount': 0,
#   'publishedAt': '2026-01-26T23:37:51Z',
#   'updatedAt': '2026-01-26T23:37:51Z'},
#  {'channelId': 'UCsjD7wxKCD8C62_idZQdGJg',
#   'videoId': '_xOnGP_Js1A',
#   'textDisplay': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#   'textOriginal': '아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.',
#   'authorDisplayName': '@새벽초승달-b5l',
# ...

# %% [markdown]
# # 5. 데이터 프레임 만들기 & 저장하기

# %%
import pandas as pd

df = pd.DataFrame(item_list)
df.head()
# Out:
#                   channelId      videoId  \
# 0  UCsjD7wxKCD8C62_idZQdGJg  _xOnGP_Js1A
# 1  UCsjD7wxKCD8C62_idZQdGJg  _xOnGP_Js1A
# 2  UCsjD7wxKCD8C62_idZQdGJg  _xOnGP_Js1A
# 3  UCsjD7wxKCD8C62_idZQdGJg  _xOnGP_Js1A
# 4  UCsjD7wxKCD8C62_idZQdGJg  _xOnGP_Js1A
#
#                                   textDisplay  \
# 0  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.
# 1  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.
# 2  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.
# 3  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.
# 4  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.
#
#                                  textOriginal authorDisplayName  \
# 0  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.        @새벽초승달-b5l
# 1  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.        @새벽초승달-b5l
# 2  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.        @새벽초승달-b5l
# 3  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.        @새벽초승달-b5l
# 4  아니 어떻게 이걸 지금 보게 됬지? 와 진짜 입이 안다물어질만한 공연이네요.        @새벽초승달-b5l
#
# ...

# %%
# https://www.data.go.kr/data/15077871/openapi.do 활용신청 / 인증키 받아서 신청
# 1 : query string
# 2 : param dic타입 (인코딩 하지 않아도 됨)
# from urllib .parse import unquote
# unquote(text)
